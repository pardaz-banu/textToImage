# %% [markdown]
# <a href="https://colab.research.google.com/github/pardaz-banu/textToImage/blob/main/textToImage.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import io
from PIL import Image
import matplotlib.pyplot as plt

API_URL = "https://api-inference.huggingface.co/models/stabilityai/stable-diffusion-xl-base-1.0"
headers = {"Authorization": "Bearer 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"}

def query(payload):
    response = requests.post(API_URL, headers=headers, json=payload)
    if response.status_code == 200:
        return response.content
    else:
        raise Exception(f"Failed to fetch image: {response.status_code} - {response.text}")

try:
    image_bytes = query({"inputs": "beautiful flower garden"})
    image = Image.open(io.BytesIO(image_bytes))
    # Display the image using matplotlib
    plt.imshow(image)
    plt.axis('off')  # Hide axes
    plt.show()
except Exception as e:
    print(e)
